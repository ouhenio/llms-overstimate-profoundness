# %%
import pandas as pd

# %%
df = pd.read_csv("clean_results_no_duplicates.csv")

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df = df[df['subject'] != 36]

# %%
df
# Out:
#        subject  trial  temperature  likert_score  evaluation_prompt  \
# 0            0      0            0             4                  1
# 1            0      1            0             3                  1
# 2            0      2            0             4                  1
# 3            0      3            0             2                  1
# 4            0      4            0             3                  1
# ...        ...    ...          ...           ...                ...
# 20898       35    765            1             4                 10
# 20899       35    766            1             4                 10
# 20900       35    767            1             4                 10
# 20901       35    768            1             4                 10
# 20902       35    769            1             4                 10
#
#                                                  sentece  dataset
# 0      Hidden meaning transforms unparalleled abstrac...        0
# 1      Good health imparts reality to subtle creativity.        0
# 2                   Wholeness quiets infinite phenomena.        0
# 3                  The future explains irrational facts.        0
# 4      Imagination is inside exponential space time e...        0
# ...                                                  ...      ...
# 20898  At the centre of your being you have the answe...        3
# 20899               A wet person does not fear the rain.        3
# 20900  Forgiveness means letting go of the hope for a...        3
# 20901  Only those who will risk going too far can pos...        3
# 20902  I wonder how many people I’ve looked at all my...        3
#
# [20903 rows x 7 columns]

# %%
df["subject"].value_counts()
# Out:
# subject
# 15    1232
# 33    1210
# 0     1118
# 26    1100
# 22    1100
# 9      955
# 31     940
# 21     922
# 25     886
# 11     881
# 13     880
# 30     880
# 32     869
# 10     818
# 16     770
# 35     770
# 23     687
# 6      684
# 14     585
# 12     475
# 4      440
# 34     420
# 36     416
# 8      362
# 3      349
# 19     334
# 7      256
# 1      250
# 5      248
# 17     142
# 20      80
# 24      60
# 27      40
# 28      40
# 29      40
# 2       40
# 18      40
# Name: count, dtype: int64

# %%
len(df)
# Out:
# 21319

# %%
(2 * 10 * 110)
# Out:
# 2200

# %%
no_score_df = df.drop('likert_score', axis=1)
all_measured_experiments = no_score_df.to_dict(orient='records')

# %%
from rate_sentences import load_sentences, assign_dataset_to_sentences

# %%
bs_sentences = assign_dataset_to_sentences(load_sentences("./data/BS.xlsx"), "0")
bs_sentences_new = assign_dataset_to_sentences(
    load_sentences("./data/New_BS.xlsx"), "1"
)
bs_sentences_generated = assign_dataset_to_sentences(
    load_sentences("./data/BS_generated.xlsx", use_header=True), "2"
)
motivational_sentences = assign_dataset_to_sentences(
    load_sentences("./data/Motivational.xlsx"), "3"
)
mundane_sentences = assign_dataset_to_sentences(
    load_sentences("./data/Mundane.xlsx"), "4"
)

all_sentences = (
    bs_sentences
    + bs_sentences_generated
    + bs_sentences_new
    + mundane_sentences
    + motivational_sentences
)

# %%
from prompts import EVALUATION_PROMPTS_DICT

TEMPERATURES = {"0": 0.1, "1": 0.7}
NUM_SUBJECTS = 35

NUM_SENTENCES = len(all_sentences)
NUM_TEMPERATURES = len(TEMPERATURES)
NUM_EVALUATION_PROMPTS = len(EVALUATION_PROMPTS_DICT)
TOTAL_TRIALS = (
    NUM_SUBJECTS * NUM_SENTENCES * NUM_TEMPERATURES * NUM_EVALUATION_PROMPTS
)

# %%
all_experiments = []

for subject in range(NUM_SUBJECTS):
    trial = 0
    for (temperature_type, temperature_value) in TEMPERATURES.items():
        for (evaluation_type, evaluation_prompt) in EVALUATION_PROMPTS_DICT.items():
            for num_sentence in range(NUM_SENTENCES):
                sentence = all_sentences[num_sentence]["sentence"]
                dataset = all_sentences[num_sentence]["dataset"]
                experiment = {
                    "subject": subject,
                    "trial": trial,
                    "temperature": int(temperature_type),
                    "evaluation_prompt": int(evaluation_type),
                    "sentence": sentence,
                    "dataset": int(dataset)
                }
                all_experiments.append(experiment)
                trial += 1

# %%
df_all_experiments = pd.DataFrame(all_experiments)
df_all_measured_experiments = pd.DataFrame(all_measured_experiments)

# %%
df_all_experiments.columns
# Out:
# Index(['subject', 'trial', 'temperature', 'evaluation_prompt', 'sentence',
#        'dataset'],
#       dtype='object')

# %%
cols_to_cast = ['subject', 'trial', 'temperature', 'evaluation_prompt', 'dataset']
for df in [df_all_experiments, df_all_measured_experiments]:
    for col in cols_to_cast:
        df[col] = df[col].astype(int)

# %%
df_all_measured_experiments.columns.equals(df_all_experiments.columns)
# Out:
# True

# %%
len(df_all_experiments) + len(df_all_measured_experiments)
# Out:
# 97903

# %%
merged = pd.concat([df_all_experiments, df_all_measured_experiments])

# %%
merged = merged.drop('trial', axis=1)

# %%
to_do = merged.drop_duplicates(keep=False)

# %%
to_do = to_do[to_do['subject'] != 35]
first_batch = list(to_do["subject"].value_counts().tail(10).index)
first_batch = to_do[to_do['subject'].isin(first_batch)]

first_batch.to_csv('first_batch.csv', index=False)

# %%
df_all_measured_experiments
# Out:
#        subject  trial  temperature  evaluation_prompt  \
# 0            0      0            0                  1
# 1            0      1            0                  1
# 2            0      2            0                  1
# 3            0      3            0                  1
# 4            0      4            0                  1
# ...        ...    ...          ...                ...
# 20898       35    765            1                 10
# 20899       35    766            1                 10
# 20900       35    767            1                 10
# 20901       35    768            1                 10
# 20902       35    769            1                 10
#
#                                                 sentence  dataset
# 0      Hidden meaning transforms unparalleled abstrac...        0
# 1      Good health imparts reality to subtle creativity.        0
# 2                   Wholeness quiets infinite phenomena.        0
# 3                  The future explains irrational facts.        0
# 4      Imagination is inside exponential space time e...        0
# ...                                                  ...      ...
# 20898  At the centre of your being you have the answe...        3
# 20899               A wet person does not fear the rain.        3
# 20900  Forgiveness means letting go of the hope for a...        3
# 20901  Only those who will risk going too far can pos...        3
# 20902  I wonder how many people I’ve looked at all my...        3
#
# [20903 rows x 6 columns]

# %%
df_all_experiments
# Out:
#        subject  trial  temperature  evaluation_prompt  \
# 0            0      0            0                  1
# 1            0      1            0                  1
# 2            0      2            0                  1
# 3            0      3            0                  1
# 4            0      4            0                  1
# ...        ...    ...          ...                ...
# 76995       34   2195            1                 10
# 76996       34   2196            1                 10
# 76997       34   2197            1                 10
# 76998       34   2198            1                 10
# 76999       34   2199            1                 10
#
#                                                 sentence  dataset
# 0      Hidden meaning transforms unparalleled abstrac...        0
# 1      Good health imparts reality to subtle creativity.        0
# 2                   Wholeness quiets infinite phenomena.        0
# 3                  The future explains irrational facts.        0
# 4      Imagination is inside exponential space time e...        0
# ...                                                  ...      ...
# 76995  At the centre of your being you have the answe...        3
# 76996               A wet person does not fear the rain.        3
# 76997  Forgiveness means letting go of the hope for a...        3
# 76998  Only those who will risk going too far can pos...        3
# 76999  I wonder how many people I’ve looked at all my...        3
#
# [77000 rows x 6 columns]

# %%
print(all_experiments[0])
print(all_measured_experiments[0])
# Out:
# {'subject': 0, 'trial': 0, 'temperature': 0, 'evaluation_prompt': 1, 'sentence': 'Hidden meaning transforms unparalleled abstract beauty.', 'dataset': 0}
# {'subject': 0, 'trial': 0, 'temperature': 0, 'evaluation_prompt': 1, 'sentence': 'Hidden meaning transforms unparalleled abstract beauty.', 'dataset': 0}

# %%
not_in_all = []
for experiment in all_measured_experiments:
    if experiment in all_experiments:
        pass
    else:
        not_in_all.append(experiment)

# %%
len(not_in_all)
# Out:
# 18451

# %%
not_in_all[0]
# Out:
# {'subject': 0,
#  'trial': 880,
#  'temperature': 0,
#  'evaluation_prompt': 9,
#  'sentence': 'Most people enjoy some sort of music.',
#  'dataset': 4}

# %%
all_experiments[880:1000]
# Out:
# [{'subject': 0,
#   'trial': 880,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Hidden meaning transforms unparalleled abstract beauty.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 881,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Good health imparts reality to subtle creativity.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 882,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Wholeness quiets infinite phenomena.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 883,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The future explains irrational facts.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 884,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Imagination is inside exponential space time events.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 885,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Your consciousness gives rise to a jumble of neural networks.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 886,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Your movement transforms universal observations.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 887,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Perceptual reality transcends subtle truth.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 888,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The invisible is beyond new timelessness.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 889,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The unexplainable undertakes intrinsic experiences.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 890,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'We are in the midst of a self-aware blossoming of being that will align us with the nexus itself.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 891,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Consciousness consists of frequencies of quantum energy. “Quantum” means an unveiling of the unrestricted.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 892,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Consciousness is the growth of coherence, and of us.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 893,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'We are in the midst of a high-frequency blossoming of interconnectedness that will give us access to the quantum soup itself.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 894,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Today, science tells us that the essence of nature is joy. ',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 895,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'As you self-actualize, you will enter into infinite empathy that transcends understanding. ',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 896,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The infinite is calling to us via superpositions of possibilities.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 897,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'We are being called to explore the totality itself as an interface between serenity and intuition.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 898,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Throughout history, humans have been interacting with the dreamscape via bio-electricity.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 899,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The future will be an astral unveiling of inseparability.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 900,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Attention and intention are the mechanics of manifestation.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 901,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Our minds extend across space and time as waves in the ocean of the one mind.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 902,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Nature is a self-regulating ecosystem of awareness.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 903,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'We are non-local beings that localize as a dot then inflate to become non-local again. The universe is mirrored in us.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 904,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Mechanics of Manifestation: Intention, detachment, centered in being allowing juxtaposition of possibilities to unfold.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 905,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Mind and matter are subtle and dense vibrations of consciousness (spirit).',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 906,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'We are not an emergent property of a mechanical universe but the seasonal activity of a living cosmos.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 907,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Every material particle is a relationship of probability waves in a field of infinite possibilities. You are that.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 908,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'As beings of light we are local and non-local, time bound and timeless actuality and possibility.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 909,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Matter is the experience in consciousness of a deeper non-material reality.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 910,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Hidden demeaning transforms unparalleled abstract beauty.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 911,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Good healthtech imparts reality to subtle creativity.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 912,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Wholeness quiets infinite phenomenon.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 913,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The Futureproof explains irrational factsheets.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 914,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Reimagination is inside exponential spacetime event.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 915,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Your consciousness gives rise to a jumble of neural networks.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 916,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Your radicalization transforms universal observations.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 917,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Perceptual reality transcends subtle kruth.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 918,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The invisible is beyond any new effortlessness.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 919,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The unexplainable undertakes intrinsic experience.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 920,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'We are in the midst of a oneself-aware blooming of being that will align us with the Conexus itself.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 921,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Consciousness consists of transmitters of quantum bioenergy. "Quantum" means an unveiling of the unrestricted.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 922,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Subconsciousness is the penultimate source of coherence and of us.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 923,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'We are in the midst of a high-frequency blossoming of interconnectedness that will give us access to the quantum soup itself.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 924,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Today, technoscience tells us that the true essence of humanness is joy.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 925,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'As you self-actualize, you will enter into infinite empathy that transcends misunderstandings.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 926,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The Twinfinite is calling to us via superposition of possibility.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 927,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'We are being called to explore the generality itself as a configuration between serenity and conception.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 928,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Throughout ethnohistory, humans have been interacting with the dreamlike via biochemicals-electricity.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 929,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The future will be an astral relaunching of movability.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 930,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Attention and intention are the mechanics of manifestations.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 931,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Our minds extend across all space and time as shockwaves in the Oceania of the One Mind.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 932,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Nature is a oneself-regulating ecosystem of rareness.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 933,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'We are non-local metahumans that localize as dots, then inflate to become non-local again. The universe is mirrored in us.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 934,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Mechanics of manifestation: intention, detachment, centered in being, allowing the exposition of possibilities to unfold.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 935,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Mind and matter are subtle and dense vibrations of consciousness (spiritedness).',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 936,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'We are not an emergent property of a mechanical universe, but the seasonal activity of a living cosmos.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 937,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Every material quasiparticle is a relationship of improbability shockwaves in a field of infinite possibilities. You are that.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 938,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'As creatures of Plight, we are local and non-local, time-bound and timeless, with believability and possibilities.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 939,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Matter is the experience in unconsciousness of deeper non-material realities.',
#   'dataset': 2},
#  {'subject': 0,
#   'trial': 940,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The mind is the ground of total acceptance of bliss.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 941,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Greatness drives an abundance of balance.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 942,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Your desire is the foundation of spiritual brightness.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 943,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Death comprehends great energy.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 944,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The Higgs boson influences immortal choices.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 945,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Qualia heals irrational creativity.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 946,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Eternal stillness explains cosmic boundaries.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 947,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Imagination is entangled in your own joy.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 948,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Orderliness compliments the doorway to genes.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 949,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'A single particle is rooted in boundless molecules.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 950,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Interdependence fears intricate observations.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 951,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Your body belongs to the progressive expansion of success.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 952,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Non-judgment is mirrored in karmic love.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 953,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Our consciousness shapes the barrier of positivity.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 954,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The ego imparts reality to the flow of photons.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 955,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Consciousness consists of psionic wave oscillations of quantum energy. ',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 956,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Rebirth is the nature of transformation, and of us.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 957,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Today, science tells us that the essence of nature is empathy.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 958,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The goal of ultra-sentient particles is to plant the seeds of intuition rather than delusion.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 959,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Ecstasy is the driver of power.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 960,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The grid is buzzing with superpositions of possibilities.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 961,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The biosphere is beaming with electromagnetic forces.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 962,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'You and I are adventurers of the nexus.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 963,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The goal of transmissions is to plant the seeds of inseparability rather than turbulence.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 964,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'To navigate the quest is to become one with it.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 965,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'This life is nothing short of an invocation explosion of sentient will.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 966,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Interconnectedness requires exploration.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 967,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'By unfolding, we self-actualize.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 968,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The cosmos is aglow with sub-atomic particles.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 969,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'You and I are spiritual brothers and sisters of the universe.',
#   'dataset': 1},
#  {'subject': 0,
#   'trial': 970,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Newborn babies require constant attention.',
#   'dataset': 4},
#  {'subject': 0,
#   'trial': 971,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Most people enjoy some sort of music.',
#   'dataset': 4},
#  {'subject': 0,
#   'trial': 972,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Lazy people usually don’t succeed in life.',
#   'dataset': 4},
#  {'subject': 0,
#   'trial': 973,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'A balanced diet is important for maintaining good health.',
#   'dataset': 4},
#  {'subject': 0,
#   'trial': 974,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Human cultures often differ from each other quite a bit.',
#   'dataset': 4},
#  {'subject': 0,
#   'trial': 975,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'People often have very bizarre dreams.',
#   'dataset': 4},
#  {'subject': 0,
#   'trial': 976,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Higher rates of unemployment typically follow economic downturns.',
#   'dataset': 4},
#  {'subject': 0,
#   'trial': 977,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Some things have very distinct smells.',
#   'dataset': 4},
#  {'subject': 0,
#   'trial': 978,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Some people have poor taste in clothing.',
#   'dataset': 4},
#  {'subject': 0,
#   'trial': 979,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Children sometimes look a lot like their parents.',
#   'dataset': 4},
#  {'subject': 0,
#   'trial': 980,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Your teacher can open the door, but you must enter by yourself.',
#   'dataset': 3},
#  {'subject': 0,
#   'trial': 981,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'The creative adult is the child who survived. ',
#   'dataset': 3},
#  {'subject': 0,
#   'trial': 982,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'A river cuts through a rock, not because of its power but its persistence.',
#   'dataset': 3},
#  {'subject': 0,
#   'trial': 983,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': "All endings are also beginnings. We just don't know it at the time.",
#   'dataset': 3},
#  {'subject': 0,
#   'trial': 984,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Art and love are the same thing: It’s the process of seeing yourself in things that are not you.',
#   'dataset': 3},
#  {'subject': 0,
#   'trial': 985,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'At the centre of your being you have the answer; you know who you are and you know what you want.',
#   'dataset': 3},
#  {'subject': 0,
#   'trial': 986,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'A wet person does not fear the rain.',
#   'dataset': 3},
#  {'subject': 0,
#   'trial': 987,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Forgiveness means letting go of the hope for a better past.',
#   'dataset': 3},
#  {'subject': 0,
#   'trial': 988,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'Only those who will risk going too far can possibly find out how far one can go.',
#   'dataset': 3},
#  {'subject': 0,
#   'trial': 989,
#   'temperature': 0,
#   'evaluation_prompt': 9,
#   'sentence': 'I wonder how many people I’ve looked at all my life and never seen.',
#   'dataset': 3},
#  {'subject': 0,
#   'trial': 990,
#   'temperature': 0,
#   'evaluation_prompt': 10,
#   'sentence': 'Hidden meaning transforms unparalleled abstract beauty.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 991,
#   'temperature': 0,
#   'evaluation_prompt': 10,
#   'sentence': 'Good health imparts reality to subtle creativity.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 992,
#   'temperature': 0,
#   'evaluation_prompt': 10,
#   'sentence': 'Wholeness quiets infinite phenomena.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 993,
#   'temperature': 0,
#   'evaluation_prompt': 10,
#   'sentence': 'The future explains irrational facts.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 994,
#   'temperature': 0,
#   'evaluation_prompt': 10,
#   'sentence': 'Imagination is inside exponential space time events.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 995,
#   'temperature': 0,
#   'evaluation_prompt': 10,
#   'sentence': 'Your consciousness gives rise to a jumble of neural networks.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 996,
#   'temperature': 0,
#   'evaluation_prompt': 10,
#   'sentence': 'Your movement transforms universal observations.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 997,
#   'temperature': 0,
#   'evaluation_prompt': 10,
#   'sentence': 'Perceptual reality transcends subtle truth.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 998,
#   'temperature': 0,
#   'evaluation_prompt': 10,
#   'sentence': 'The invisible is beyond new timelessness.',
#   'dataset': 0},
#  {'subject': 0,
#   'trial': 999,
#   'temperature': 0,
#   'evaluation_prompt': 10,
#   'sentence': 'The unexplainable undertakes intrinsic experiences.',
#   'dataset': 0}]

# %%
all = all_experiments + all_measured_experiments

# %%
pd.DataFrame(all).drop_duplicates(keep=False)
# Out:
#        subject  temperature  evaluation_prompt  dataset  \
# 0           16            0                  6        1
# 1           21            1                  6        1
# 2           26            1                  3        3
# 3            6            1                  7        2
# 4            0            1                  1        0
# ...        ...          ...                ...      ...
# 95437       34            0                  2        3
# 95438       20            1                  6        2
# 95439        5            1                 10        2
# 95440       18            0                  9        0
# 95441       23            1                  6        2
#
#                                                 sentence  trial
# 0      The grid is buzzing with superpositions of pos...    630
# 1        The ego imparts reality to the flow of photons.   1724
# 2      At the centre of your being you have the answe...   1425
# 3      Mind and matter are subtle and dense vibration...   1815
# 4      We are in the midst of a self-aware blossoming...   1110
# ...                                                  ...    ...
# 95437  Your teacher can open the door, but you must e...    210
# 95438  Your consciousness gives rise to a jumble of n...   1685
# 95439  Every material quasiparticle is a relationship...   2147
# 95440  Hidden meaning transforms unparalleled abstrac...    880
# 95441        Perceptual reality transcends subtle kruth.   1687
#
# [95442 rows x 6 columns]

# %%
all = [dict(s) for s in set(frozenset(d.items()) for d in all)]

# %%
len(all)
# Out:
# 95442

# %%
comparison_result = df_all_experiments.compare(df_all_measured_experiments, keep_shape=True)
different_rows = comparison_result[comparison_result['_merge'] != 'both']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 comparison_result = df_all_experiments.compare(df_all_measured_experiments, keep_shape=True)
#       2 different_rows = comparison_result[comparison_result['_merge'] != 'both']
#
# File ~/miniconda3/envs/bs/lib/python3.10/site-packages/pandas/core/frame.py:7713, in DataFrame.compare(self, other, align_axis, keep_shape, keep_equal, result_names)
#    7591 @doc(
#    7592     _shared_docs["compare"],
#    7593     """
#    (...)
#    7711     result_names: Suffixes = ("self", "other"),
#    7712 ) -> DataFrame:
# -> 7713     return super().compare(
#    7714         other=other,
#    7715         align_axis=align_axis,
#    7716         keep_shape=keep_shape,
#    7717         keep_equal=keep_equal,
#    7718         result_names=result_names,
#    7719     )
#
# File ~/miniconda3/envs/bs/lib/python3.10/site-packages/pandas/core/generic.py:9212, in NDFrame.compare(self, other, align_axis, keep_shape, keep_equal, result_names)
#    9207     cls_self, cls_other = type(self).__name__, type(other).__name__
#    9208     raise TypeError(
#    9209         f"can only compare '{cls_self}' (not '{cls_other}') with '{cls_self}'"
#    9210     )
# -> 9212 mask = ~((self == other) | (self.isna() & other.isna()))
#    9213 mask.fillna(True, inplace=True)
#    9215 if not keep_equal:
#
# File ~/miniconda3/envs/bs/lib/python3.10/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File ~/miniconda3/envs/bs/lib/python3.10/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/miniconda3/envs/bs/lib/python3.10/site-packages/pandas/core/frame.py:7442, in DataFrame._cmp_method(self, other, op)
#    7439 def _cmp_method(self, other, op):
#    7440     axis: Literal[1] = 1  # only relevant for Series other case
# -> 7442     self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)
#    7444     # See GH#4537 for discussion of scalar op behavior
#    7445     new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# File ~/miniconda3/envs/bs/lib/python3.10/site-packages/pandas/core/ops/__init__.py:313, in align_method_FRAME(left, right, axis, flex, level)
#     311             left, right = left.align(right, join="outer", level=level, copy=False)
#     312         else:
# --> 313             raise ValueError(
#     314                 "Can only compare identically-labeled (both index and columns) "
#     315                 "DataFrame objects"
#     316             )
#     317 elif isinstance(right, ABCSeries):
#     318     # axis=1 is default for DataFrame-with-Series op
#     319     axis = left._get_axis_number(axis) if axis is not None else 1
#
# ValueError: Can only compare identically-labeled (both index and columns) DataFrame objects

# %%
differences = [d for d in all_experiments if d not in all_measured_experiments] + [d for d in all_measured_experiments if d not in all_experiments]

# %%
len(differences)
# Out:
# 93000

# %%
set_list1 = set(tuple(sorted(d.items())) for d in sorted(all_experiments))
set_list2 = set(tuple(sorted(d.items())) for d in sorted(all_measured_experiments))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 set_list1 = set(tuple(sorted(d.items())) for d in sorted(all_experiments))
#       2 set_list2 = set(tuple(sorted(d.items())) for d in sorted(all_measured_experiments))
#
# TypeError: '<' not supported between instances of 'dict' and 'dict'

# %%
L=[
    {'id': 1, 'name': 'john', 'age': 34},
    {'id': 1, 'name': 'john', 'age': 34},
    {'id': 2, 'name': 'hanna', 'age': 30},
]
pd.DataFrame(L).drop_duplicates(keep=False)
# Out:
#    id   name  age
# 2   2  hanna   30
